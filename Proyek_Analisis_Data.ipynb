# %% [markdown]
# # Proyek Analisis Data: Bike Sharing Dataset
# - **Nama:** Pratisia Tri Handayani
# - **Email:** pratisiatrihndyni@gmail.com
# - **ID Dicoding:** tissays

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Dari tahun 2011-2012, pada musim apa sepeda banyak disewa (baik oleh pengguna biasa/terdaftar)?
# - Dari tahun 2011-2012, pada cuaca apa sepeda banyak disewa (baik oleh pengguna biasa/terdaftar)?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ed84f584-a6e7-4f40-8443-ade58b78264a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ed84f584-a6e7-4f40-8443-ade58b78264a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
day_df = pd.read_csv("day.csv")
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
hour_df = pd.read_csv("hour.csv")
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# **Insight:**
# - Tabel pertama menunjukkan 5 baris pertama dari DataFrame `hour_df`
# - Tabel kedua menunjukkan 5 baris pertama dari DataFrame `hour_df`

# %% [markdown]
# ### Assessing Data

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
day_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
print("Jumlah duplikasi: ", day_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
hour_df.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
print("Jumlah duplikasi: ", hour_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# **Insight:**
# - Pada data day_df terdapat kesalahan tipe data untuk kolom `dteday` yang seharusnya sebagai tipe data datetime bukan object.
# - Pada data hour_df terdapat kesalahan tipe data untuk kolom `dteday` yang seharusnya sebagai tipe data datetime bukan object.

# %% [markdown]
# ### Cleaning Data

# %%
datetime_columns = ["dteday"]

for column in datetime_columns:
  day_df[column] = pd.to_datetime(day_df[column])

# %%
datetime_columns = ["dteday"]

for column in datetime_columns:
  hour_df[column] = pd.to_datetime(hour_df[column])

# %% [markdown]
# **Insight:**
# - Kode diatas digunakan untuk mengubah tipe data pada kolom dteday menjadi datetime

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(12)
# memory usage: 2.3 MB

# %% [markdown]
# Akan dilakukan perubahan format keterangan pada *season, weathersit* guna memudahkan dalam visualisasi

# %%
day_df["season"] = day_df["season"].map({
    1:"spring", 2:"summer", 3:"fall", 4:"winter"
})

day_df["weathersit"] = day_df["weathersit"].map({
    1: "Clear/Few clouds/Partly cloudy",
    2: "Mist + Cloudy\ Mist",
    3: "Light Snow/Light Rain",
    4: "Heavy Rain/ Snow"
})

day_df.head()
# Out:
#    instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1 2011-01-01  spring   0     1        0        6           0
# 1        2 2011-01-02  spring   0     1        0        0           0
# 2        3 2011-01-03  spring   0     1        0        1           1
# 3        4 2011-01-04  spring   0     1        0        2           1
# 4        5 2011-01-05  spring   0     1        0        3           1
#
#                        weathersit      temp     atemp       hum  windspeed  \
# 0             Mist + Cloudy\ Mist  0.344167  0.363625  0.805833   0.160446
# 1             Mist + Cloudy\ Mist  0.363478  0.353739  0.696087   0.248539
# 2  Clear/Few clouds/Partly cloudy  0.196364  0.189405  0.437273   0.248309
# 3  Clear/Few clouds/Partly cloudy  0.200000  0.212122  0.590435   0.160296
# 4  Clear/Few clouds/Partly cloudy  0.226957  0.229270  0.436957   0.186900
#
#    casual  registered   cnt
# 0     331         654   985
# 1     131         670   801
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
day_df.groupby(by="season").agg({
    "casual"  : "sum",
    "registered" : "sum",
    "cnt" : "sum"
}).sort_values(by="cnt", ascending=False)
# Out:
#         casual  registered      cnt
# season
# fall    226091      835038  1061129
# summer  203522      715067   918589
# winter  129782      711831   841613
# spring   60622      410726   471348

# %% [markdown]
# **Insight:**
# - Diperoleh bahwa pada musim gugur (*fall*) memiliki jumlah sewa sepeda terbanyak dengan total 226091 pengguna biasa dan 835038 pengguna terdaftar

# %%
day_df.groupby(by="weathersit").agg({
    "casual"  : "sum",
    "registered" : "sum",
    "cnt" : "sum"
}).sort_values(by="cnt", ascending=False)
# Out:
#                                 casual  registered      cnt
# weathersit
# Clear/Few clouds/Partly cloudy  446346     1811606  2257952
# Mist + Cloudy\ Mist             169776      827082   996858
# Light Snow/Light Rain             3895       33974    37869

# %% [markdown]
# **Insight:**
# - Diperoleh bahwa pada cuaca *Clear, Few clouds, Partly cloudy, Partly cloudy* memiliki jumlah sewa sepeda terbanyak dengan total 446346 pengguna biasa dan 1811606 pengguna terdaftar

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Dari tahun 2011-2012, pada musim apa sepeda banyak disewa (baik oleh pengguna biasa/terdaftar)?

# %%
season_sort = day_df.groupby("season")[["registered", "casual"]].sum().reset_index()

season_name = ["spring","summer", "fall", "winter"]

plt.figure(figsize=(10, 6))

plt.bar(
    season_sort["season"],
    season_sort["registered"],
    label="Registered",
    color="tab:blue"
)

plt.bar(
    season_sort["season"],
    season_sort["casual"],
    label="Casual",
    color="tab:green",
)

plt.xlabel(None)
plt.ylabel(None)
plt.title("Jumlah Penyewa Sepeda Berdasarkan Musim")
plt.legend()
plt.show()

# %% [markdown]
# ### Pertanyaan 2:Dari tahun 2011-2012, pada cuaca apa sepeda banyak disewa (baik oleh pengguna biasa/terdaftar)?

# %%
weathersit_sort = day_df.groupby("weathersit")[["registered", "casual"]].sum().reset_index()

weathersit_name = ["Clear/Few clouds/Partly cloudy", "Mist + Cloudy/ Mist", "Light Snow/Light Rain","Heavy Rain/ Snow"]

plt.figure(figsize=(10, 6))

plt.bar(
    weathersit_sort["weathersit"],
    weathersit_sort["registered"],
    label="Registered",
    color="tab:orange"
)

plt.bar(
    weathersit_sort["weathersit"],
    weathersit_sort["casual"],
    label="Casual",
    color="tab:green",
)

plt.xlabel(None)
plt.ylabel(None)
plt.title("Jumlah Penyewa Sepeda Berdasarkan Cauca")
plt.legend()
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %% [markdown]
# **Insight:**
# - Diperoleh bahwa pada musim gugur (*fall*) memiliki jumlah penyewa sepeda terbanyak
# - Diperoleh bahwa pada cuaca *Clear, Few clouds, Partly cloudy, Partly cloudy* memiliki jumlah penyewa sepeda terbanyak

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Musim gugur menjadi musim dengan penyewa terbanyak baik dari pengguna *casual* maupun *registered*. Ini menunjukkan bahwa pada musim ini lebih mendukung bagi orang-orang untuk menyewa sepeda. Sebaliknya, musim semi mempunyai jumlah penyewa sepeda paling sedikit. Meskipun musim dingin mungkin tidak ideal untuk sebagian besar aktivitas luar ruangan, jumlah pengguna *registered* tetap tinggi, hampir setara dengan musim panas dan musim gugur. Disemua musim, pengguna *registered* selalu lebih banyak dibandingkan dengan pengguna *casual*.
#
# - Cuaca cerah atau berawan ringan  menjadi cuaca paling favorit untuk bersepeda, baik oleh pengguna *registered* maupun *casual* sehingga menunjukkan bahwa cuaca ini nyaman bagi orang untuk menyewa sepeda. Sebaliknya, ketika terjadi hujan ringan atau salju ringan, jumlah penyewa menurun drastis. Namun, saat cuaca berkabut atau mendung, masih ada cukup banyak orang yang tetap menyewa sepeda, meskipun jumlahnya tidak sebanyak pada saat cuaca cerah.
